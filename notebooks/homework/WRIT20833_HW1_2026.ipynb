# %% [markdown]
# <a href="https://colab.research.google.com/github/TCU-DCDA/WRIT20833_2026/blob/main/notebooks/homework/WRIT20833_HW1_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 1 — Comparisons, Conditionals, Lists, and Loops
#
# **WRIT 20833 — Intro to Coding in the Humanities**
#
# **Student Name:** _Replace with your name_
#
# **Upload as:** `LASTNAME_HW1.ipynb`
#
# ---
#
# ## What you're doing
# This week you'll practice **comparisons, conditionals, lists, and loops** — the tools that let code make decisions and process many items at once.
#
# Every exercise is **self-contained**: the data you need is already in the cell, so you don't need any outside textbook. If you want a refresher, review **our own** materials below.

# %% [markdown]
# ## Prepare
# Before you start, review this week's course materials:
# - **Tutorial 2 — Classification Logic** (comparisons, booleans, `if`/`elif`/`else`)
# - **Tutorial 4 — Collective Memory** (lists, `for` loops, systematic processing)
# - The **String Methods / Conditionals / Loops** and **Lists / Loops** code-alongs

# %% [markdown]
# ## Required: `#comments` in every code block
# In each code cell, add `#comments` that explain **what you are trying to do** and **what you learned** (or what confused you). For example:
#
# ```python
# # I wanted to see what happens if I compare a word to a number.
# # I learned that Python raises a TypeError — you can only compare numbers to numbers.
# "apple" > 5
# ```

# %% [markdown]
# ## Part A — Comparisons & Conditionals (6 exercises)

# %% [markdown]
# **A1 — Comparing engagement.** You have like-counts for one comment on two different days.

# %%
# A1
likes_day1 = 47
likes_day2 = 52

# TODO: print whether day2 had MORE likes than day1 (a True/False comparison)
# TODO: print whether the two counts are EQUAL

# #comments:
# What did you try?
# What did you learn about comparison operators?

# %% [markdown]
# **A2 — A case-insensitive moderation check.**

# %%
# A2
comment = "This take is GARBAGE and you know it"

# TODO: print "flagged" if the comment contains "garbage" in ANY capitalization, else print "ok".
# Hint: .lower() lowercases text; the `in` operator checks if one string is inside another.

# #comments:
# Who decides which words count as "flagged"?
# What might a rule like this get wrong?

# %% [markdown]
# **A3 — Classifying a person by age.** *(Recall Tutorial 2: Classification Logic.)*

# %%
# A3
age = 28

# TODO: write if / elif / else that prints:
#   "youth"        if age is under 18
#   "working age"  if age is 18 to 59
#   "elder"        if age is 60 or older

# #comments:
# What assumptions does this 3-category system bake in?
# (Recall the Bellevue exercise: how does a simple comparison become a social category?)

# %% [markdown]
# **A4 — An edge case: predict, then run.**

# %%
# A4 — predict, then run
# First PREDICT, in a comment, what `"apple" > 5` will do. THEN run this cell.
# (The try/except just lets us SEE the error without stopping the notebook --
#  you do not need to understand that syntax yet.)
try:
    print("apple" > 5)
except Exception as error:
    print("Python raised an error:", error)

# #comments:
# My prediction was:
# What does the error message teach you about comparing a string to a number?

# %% [markdown]
# **A5 — Combining conditions with `and` / `or` / `not`.**

# %%
# A5
is_registered = True
is_banned = False

# TODO: make a variable `can_post` that is True ONLY if the user IS registered AND is NOT banned. Print it.
# TODO: change the values above and re-run to test a banned user.

# #comments:
# How do `and` / `or` / `not` change the outcome?

# %% [markdown]
# **A6 — Membership testing (a preview of next week).**

# %%
# A6
stopwords = ["the", "a", "is", "and", "of"]
word = "and"

# TODO: print whether `word` is in `stopwords` (True/False)
# TODO: write if/else that prints "skip this word" if it is a stopword, else "keep this word"

# #comments:
# Why might we skip common words like these when analyzing text?

# %% [markdown]
# ## Part B — Lists & Loops, Part 1 (4 exercises)

# %% [markdown]
# **B1 — A small corpus of comments.**

# %%
# B1
comments = ["Love this", "Not sure about this", "This is wrong", "Great point"]

# TODO: print how many comments are in the list
# TODO: print the FIRST comment and the LAST comment (use indexing)

# #comments:

# %% [markdown]
# **B2 — Processing every comment with a loop.** *(Recall Tutorial 4: Collective Memory.)*

# %%
# B2
comments = ["Love this", "Not sure about this", "This is wrong", "Great point"]

# TODO: use a for-loop to print each comment AND its word count
#       (hint: a_string.split() returns a list of words)
# TODO: count how many comments have FEWER than 3 words, and print that total

# #comments:
# A loop applies the SAME rule to every item. Where could that be a problem
# when the "items" are people's words?

# %% [markdown]
# **B3 — Building a new list with `.append()`.**

# %%
# B3
comments = ["Love this", "Not sure about this", "This is wrong", "Great point"]

# TODO: create an empty list called `lengths`
# TODO: loop through `comments` and append each comment's word count to `lengths`
# TODO: print `lengths`

# #comments:

# %% [markdown]
# **B4 — Finding the longest comment.**

# %%
# B4
comments = ["Love this", "Not sure about this", "This is wrong", "Great point"]

# TODO: loop through the comments and find the one with the MOST words.
#       Keep track of the longest so far in a variable as you go.
# TODO: print the longest comment.

# #comments:
# Describe your strategy for "remembering" the longest one while looping.

# %% [markdown]
# ## Part C — Lists & Loops, Part 2 (2 exercises)

# %% [markdown]
# **C1 — Combining lists, loops, and conditionals.** *(This previews next week's term-frequency homework.)*

# %%
# C1
flagged_words = ["garbage", "wrong", "stupid"]
comments = ["Love this", "This is wrong", "GARBAGE take", "Great point", "stupid idea"]

# TODO: create an empty list called `flagged`
# TODO: loop through `comments`; if a comment (lowercased) contains ANY flagged word, append it to `flagged`
# TODO: print `flagged` and how many comments were caught

# #comments:
# What does this automated filter MISS?
# (Recall Collective Memory: what happens to context and nuance at scale?)

# %% [markdown]
# **C2 — From many comments to one word list.** *(The heart of next week's term-frequency homework.)*

# %%
# C2
comments = ["Love this", "This is wrong", "I really love this", "Great great point"]

# TODO: create an empty list called `all_words`
# TODO: loop through each comment, split it into lowercase words, and add those words to `all_words`
# TODO: print the TOTAL number of words, and the number of DISTINCT words
#       (hint: set(all_words) keeps only unique items)

# #comments:
# Next week we will COUNT these words. Which word do you expect to be most common, and why?

# %% [markdown]
# ## Weekly Experiments (your own work!)
# After the required exercises, create **2–3 small experiments of your own** using this week's skills. Make them original — not copies of the exercises above.
#
# Ideas:
# - Combine a loop and a conditional in one example.
# - Test an **edge case** (a very large number, an empty list `[]`, a comment with no spaces).
# - Make something playful or artistic with loops and conditionals.
#
# It's fine if an experiment doesn't work at first — **documenting what went wrong and what you learned is worth just as much as working code.**

# %%
# Experiment 1


# #comments:
# What were you trying? What happened? What did you learn?

# %%
# Experiment 2


# #comments:
# What were you trying? What happened? What did you learn?

# %%
# Experiment 3


# #comments:
# What were you trying? What happened? What did you learn?

# %% [markdown]
# ## Submit
# - [ ] My name is at the top.
# - [ ] I completed **Part A (6)**, **Part B (4)**, **Part C (2)**, and **2–3 experiments**.
# - [ ] Every code cell has `#comments`.
# - [ ] The notebook **runs top to bottom without errors**.
# - [ ] Saved as `LASTNAME_HW1.ipynb` and uploaded to the D2L Dropbox.
#
# **Time estimate:** ~1.5–2 hrs for the exercises, ~1 hr for your experiments.
